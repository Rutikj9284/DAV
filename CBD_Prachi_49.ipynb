# %% [markdown]
# <a href="https://colab.research.google.com/github/Rutikj9284/DAV/blob/main/CBD_Prachi_49.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Missingno Library**

# %% [markdown]
# In the case of a real-world dataset, it is very common that some values in the dataset are missing. We represent these missing values as NaN (Not a Number) values. But to build a good machine learning model our dataset should be complete. That’s why we use some imputation techniques to replace the NaN values with some probable values. But before doing that we need to have a good understanding of how the NaN values are distributed in our dataset.
#
# Missingno library offers a very nice way to visualize the distribution of NaN values. Missingno is a Python library and compatible with Pandas.
#
# Missingno serves as a data detective, specializing in uncovering the enigma of missing data in datasets. It offers a toolkit of visualizations and tools designed to reveal the patterns and extent of missing values. With its clever name derived from "missing data" and "no values," Missingno provides data scientists and analysts with a compass to navigate the complexities of incomplete information. By offering visual insights like matrix plots, heatmaps, and dendrograms, this library transforms the challenge of missing data into an opportunity for deeper understanding and informed decision-making in data analysis and preprocessing.

# %%
pip install missingno
# Out:
# Requirement already satisfied: missingno in /usr/local/lib/python3.10/dist-packages (0.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from missingno) (1.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from missingno) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from missingno) (1.11.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from missingno) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn->missingno) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn->missingno) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
import missingno as msno
import pandas as pd
import numpy as np

# %% [markdown]
# # **Missingno on sample dataframe**

# %%
# Creating a sample DataFrame with missing values
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [np.nan, 2, 3, np.nan, 5],
    'C': [1, 2, 3, 4, 5],
    'D': [1, np.nan, np.nan, np.nan, np.nan]
}

# %%
df = pd.DataFrame(data)

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.bar(df, color="Lightblue")
# Out:
# <Axes: >

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %%
msno.dendrogram(df)
# Out:
# <Axes: >

# %% [markdown]
# # **Missingno on dataset**
#
# dataset: https://www.kaggle.com/datasets/thedevastator/uncovering-factors-that-affect-used-car-prices?resource=download

# %%
df = pd.read_csv("autos.csv")

# %%
missing_values = df.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Missing values in each column:
# index                     0
# dateCrawled               0
# name                      0
# seller                    0
# offerType                 0
# price                     0
# abtest                    0
# vehicleType            2308
# yearOfRegistration        0
# gearbox                1189
# powerPS                   0
# model                  1175
# kilometer                 1
# monthOfRegistration       1
# fuelType               2018
# brand                     1
# notRepairedDamage      4316
# dateCreated               1
# nrOfPictures              1
# postalCode                1
# lastSeen                  1
# dtype: int64

# %%
rows_with_missing_values = df[df.isnull().any(axis=1)]
print("\nRows with missing values:")
print(rows_with_missing_values)
# Out:
# Rows with missing values:
#        index          dateCrawled  \
# 0          0  2016-03-24 11:52:17
# 1          1  2016-03-24 10:58:45
# 2          2  2016-03-14 12:52:21
# 8          8  2016-04-04 23:42:13
# 9          9  2016-03-17 10:53:50
# ...      ...                  ...
# 22111  22111  2016-03-07 23:36:56
# 22112  22112  2016-03-29 05:36:21
# 22113  22113  2016-03-31 22:56:05
# 22116  22116  2016-03-16 15:54:17
# 22121  22121  2016-03-17 18:58:02
#
#                                                     name  seller offerType  \
# 0                                             Golf_3_1.6  privat   Angebot
# 1                                   A5_Sportback_2.7_Tdi  privat   Angebot
# 2                         Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 8                   Ford_C___Max_Titanium_1_0_L_EcoBoost  privat   Angebot
# 9      VW_Golf_4_5_tuerig_zu_verkaufen_mit_Anhaengerk...  privat   Angebot
# ...                                                  ...     ...       ...
# 22111             PEUGEOT_206_1.4_BENZIN_TUV_BIS_05/2017  privat   Angebot
# 22112  !!Ich_suche_ein_schicken_9sitzer_Buss_zahle_bi...  privat   Angebot
# 22113                                   E250_Diesel_w124  privat   Angebot
# 22116                 Passat_Variant_2.0TDI_DPF_Highline  privat   Angebot
# 22121  T5_Multivan__6_Sitzer__2.Schiebetuer__Navi__St...  privat   Angebot
#
#        price   abtest vehicleType  yearOfRegistration    gearbox  ...  \
# 0        480     test         NaN                1993    manuell  ...
# 1      18300     test       coupe                2011    manuell  ...
# 2       9800     test         suv                2004  automatik  ...
# 8      14500  control         bus                2014    manuell  ...
# 9        999     test  kleinwagen                1998    manuell  ...
# ...      ...      ...         ...                 ...        ...  ...
# 22111    699     test   limousine                2004    manuell  ...
# 22112      0  control         NaN                2000        NaN  ...
# 22113   1700     test   limousine                1991    manuell  ...
# 22116   2600     test       kombi                2005    manuell  ...
# 22121  15700  control         bus                2005    manuell  ...
#
#           model kilometer  monthOfRegistration  fuelType           brand  \
# 0          golf  150000.0                  0.0    benzin      volkswagen
# 1           NaN  125000.0                  5.0    diesel            audi
# 2         grand  125000.0                  8.0    diesel            jeep
# 8         c_max   30000.0                  8.0    benzin            ford
# 9          golf  150000.0                  0.0       NaN      volkswagen
# ...         ...       ...                  ...       ...             ...
# 22111   2_reihe  150000.0                  5.0    benzin         peugeot
# 22112       NaN  150000.0                 12.0       NaN  sonstige_autos
# 22113  e_klasse  150000.0                 10.0    diesel   mercedes_benz
# 22116    passat  150000.0                  6.0    diesel      volkswagen
# 22121    transp       NaN                  NaN       NaN             NaN
#
#       notRepairedDamage          dateCreated nrOfPictures  postalCode  \
# 0                   NaN  2016-03-24 00:00:00          0.0     70435.0
# 1                    ja  2016-03-24 00:00:00          0.0     66954.0
# 2                   NaN  2016-03-14 00:00:00          0.0     90480.0
# 8                   NaN  2016-04-04 00:00:00          0.0     94505.0
# 9                   NaN  2016-03-17 00:00:00          0.0     27472.0
# ...                 ...                  ...          ...         ...
# 22111               NaN  2016-03-07 00:00:00          0.0     85258.0
# 22112               NaN  2016-03-29 00:00:00          0.0     26131.0
# 22113               NaN  2016-03-31 00:00:00          0.0     66763.0
# 22116               NaN  2016-03-16 00:00:00          0.0     40210.0
# 22121               NaN                  NaN          NaN         NaN
#
#                   lastSeen
# 0      2016-04-07 03:16:57
# 1      2016-04-07 01:46:50
# 2      2016-04-05 12:47:46
# 8      2016-04-04 23:42:13
# 9      2016-03-31 17:17:06
# ...                    ...
# 22111  2016-03-11 03:46:56
# 22112  2016-03-30 23:46:51
# 22113  2016-04-02 20:44:43
# 22116  2016-03-16 16:41:15
# 22121                  NaN
#
# [6568 rows x 21 columns]

# %% [markdown]
# **Matrix Visualization**
#
# The matrix visualization provides a compact overview of the completeness of the dataset. It is a grid where each row represents a variable in the DataFrame, and each column represents an entry (observation) in the DataFrame.

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# **Bar Chart Visualization**
#
# The bar chart visualization presents a bar plot that illustrates the number or percentage of missing values in each column of the DataFrame.

# %%
msno.bar(df, color="Lightblue")
# Out:
# <Axes: >

# %% [markdown]
# **Heatmap Visualization**
#
# The heatmap visualization presents a graphical representation of the correlation between missing values in different columns of the DataFrame.

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %% [markdown]
# **Dendrogram Visualization**
#
# The dendrogram visualization displays hierarchical clustering of variables based on the presence or absence of missing values.

# %%
msno.dendrogram(df)
# Out:
# <Axes: >

# %% [markdown]
# # **Advantages of Missingno:**
# **1. Quick Visualization:** Missingno offers rapid visualizations that help identify the distribution and patterns of missing values in a dataset, enabling quick understanding.
#
# **2. Easy Integration:** It seamlessly integrates with Pandas, one of the most widely used data manipulation libraries in Python.
#
# **3. Informative Visuals:** The matrix plot, bar chart, heatmap, and dendrogram provide a comprehensive overview of missing values, aiding data analysts in making informed decisions.
#
# **4. Imputation Strategies:** Missingno doesn't just visualize; it also offers methods to impute, drop, or handle missing values, enhancing data cleaning and preprocessing.
#
# **5. Data Quality Insights:** By visualizing missing value correlations, users can spot potential data quality issues and take corrective actions.

# %% [markdown]
# # **Disadvantages of Missingno:**
# **1. Simplicity:** While great for basic analysis, Missingno's visualizations might not suffice for complex missing data analysis or large datasets.
#
# **2. Limited Statistics:** Missingno primarily focuses on visual insights, so it might lack certain advanced statistical metrics for detailed analysis.
#
# **3. Not a Replacement:** It should be used as a complementary tool alongside other data preprocessing and missing value handling techniques.
#
# **4. Data Complexity:** For datasets with high complexity or numerous features, interpreting visualizations might become overwhelming.
#
# **5. Imputation Limitations:** The imputation methods provided are basic, which might not cover all scenarios; users might need more sophisticated imputation techniques.
