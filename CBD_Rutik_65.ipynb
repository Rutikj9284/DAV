# %% [markdown]
# <a href="https://colab.research.google.com/github/Rutikj9284/DAV/blob/main/CBD_Rutik_65.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Plotly :- Plotly is a Python graphing library used for creating interactive, publication-quality graphs and charts. It provides a high-level API that allows users to create a wide range of plots easily. plotly.express is a high-level interface for Plotly, a Python graphing library that makes interactive, publication-quality graphs online.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Import Dataset

# %%
data = pd.read_csv("stock_data.csv")

# %%
data
# Out:
#             Date   Open   High    Low  Close    Volume  Name
# 0     01-03-2006  39.69  41.22  38.79  40.91  24232729  AABA
# 1     01-04-2006  41.22  41.90  40.77  40.97  20553479  AABA
# 2     01-05-2006  40.93  41.73  40.85  41.53  12829610  AABA
# 3     01-06-2006  42.88  43.57  42.80  43.21  29422828  AABA
# 4     01-09-2006  43.10  43.66  42.82  43.42  16268338  AABA
# ...          ...    ...    ...    ...    ...       ...   ...
# 3014  12/22/2017  71.42  71.87  71.22  71.58  10979165  AABA
# 3015  12/26/2017  70.94  71.39  69.63  69.86   8542802  AABA
# 3016  12/27/2017  69.77  70.49  69.69  70.06   6345124  AABA
# 3017  12/28/2017  70.12  70.32  69.51  69.82   7556877  AABA
# 3018  12/29/2017  69.79  70.13  69.43  69.85   6613070  AABA
#
# [3019 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# Name      0
# dtype: int64

# %%
data['Date'] = pd.to_datetime(data['Date'], errors='coerce')

# %% [markdown]
# # Plotting Different Charts

# %% [markdown]
# 1.Line chart

# %%
fig1 = px.line(data, x='Date', y='Close', title='Trend of Close Prices Over Time')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 2.Bar Chart

# %%
data['Year'] = data['Date'].dt.year
avg_volume = data.groupby('Year')['Volume'].mean().reset_index()
fig2 = px.bar(avg_volume, x='Year', y='Volume', title='Average Volume per Year')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Box Plot

# %%
fig3 = px.box(data, y='High', title='Distribution of High Prices')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Scatterplot

# %%
fig4 = px.scatter(data, x='High', y='Low', title='Relationship between High and Low Prices')
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[go.Candlestick(
    x=data['Date'],
    open=data['Open'],
    high=data['High'],
    low=data['Low'],
    close=data['Close']
)])

# Update the layout
fig.update_layout(
    title='Candlestick Chart of Stock Prices',
    xaxis_title='Date',
    yaxis_title='Price',
    xaxis_rangeslider_visible=False
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
